# %%
import re

# %%
chat1='codebasics: Hello, I am having an issue with my order # 4128859912 and abcfi3@gmail.com'
chat2='codebasics: I have a problem with my order number 4128389912'
chat3='codebasics: My order 4128894912 is having 1230456789 an issue, I  (123)-567-8912 was charged 300$ when online it says 280$'

# %%
pattern = r'\d{10}|\(\d{3}\)-\d{3}-\d{4}'

matches = re.findall(pattern, chat3)
matches
# Out:
# ['4128894912', '1230456789', '(123)-567-8912']

# %%
pattern = r'[a-z0-9A-Z_]*@[a-z0-9A-Z]*\.[a-z]*'
matches = re.findall(pattern, chat1)
matches
# Out:
# ['abcfi3@gmail.com']

# %%
chat1='codebasics: Hello, I am having an issue with my order # 412889912'
chat2='codebasics: I have a problem with my order number 412889912'
chat3='codebasics: My order 412889912 is having an issue, I was charged 300$ when online it says 280$'

# %%
pattern = r'order[^\d]*(\d*)'
matches = re.findall(pattern, chat3)
matches
# Out:
# ['412889912']

# %%
elon = "Elon Reeve Musk (/ˈiːlɒn/ EE-lon; born June 28, 1971) is a businessman and entrepreneur known for his leadership of Tesla, SpaceX, X, and xAI. Musk has been the wealthiest person in the world since 2025; as of February 2026, Forbes estimates his net worth to be around US$852 billion."

# %%
year = r'born\s[a-zA-Z]*\s[0-9][0-9],\s([0-9]{4})'
month = year = r'born\s([a-zA-Z]*)\s[0-9][0-9],\s[0-9]{4}'
age_y = re.findall(year,elon)
age_m = re.findall(month,elon)
age_y
age_m
# Out:
# ['June']
